# %%
import pandas as pd
NL_LON_HALFLIFE = pd.read_csv("C:/Users/th760/OneDrive/바탕 화면/rpa 과제 자료파일/도서별 대출반감기/NL_LON_HALFLIFE_2020.csv")
NL_LON_HALFLIFE
# Out:
#          BOOK_MASTR_SEQ_NO        ISBN_NO  MUMM_LON_HALFLIFE_CO  \
# 0                   116165  9788975486456                  2765
# 1                   116168  9788976820624                   807
# 2                   116171  9788977990401                   835
# 3                   116175  9788972783497                  2566
# 4                   116177  9788932105635                  2806
# ...                    ...            ...                   ...
# 1103278            5964937  9788936430033                  2937
# 1103279            5964938  9788936430041                  2741
# 1103280            5964939  9788936430068                  2760
# 1103281            5964940  9788936430084                  3373
# 1103282            5969164  8935610666039                  4242
#
#          MXMM_LON_HALFLIFE_CO  AVRG_LON_HALFLIFE_CO  BOOK_CO
# 0                        5281                  4463        8
# 1                        6521                  4891       43
# ...

# %%
NL_LON_HALFLIFE.dtypes
# Out:
# BOOK_MASTR_SEQ_NO       int64
# ISBN_NO                 int64
# MUMM_LON_HALFLIFE_CO    int64
# MXMM_LON_HALFLIFE_CO    int64
# AVRG_LON_HALFLIFE_CO    int64
# BOOK_CO                 int64
# dtype: object

# %%
columns_to_convert = ['ISBN_NO']
NL_LON_HALFLIFE[columns_to_convert] = NL_LON_HALFLIFE[columns_to_convert].astype('string')

# %%
NL_LON_HALFLIFE.dtypes
# Out:
# BOOK_MASTR_SEQ_NO                int64
# ISBN_NO                 string[python]
# MUMM_LON_HALFLIFE_CO             int64
# MXMM_LON_HALFLIFE_CO             int64
# AVRG_LON_HALFLIFE_CO             int64
# BOOK_CO                          int64
# dtype: object

# %% [markdown]
# # 도서 키워드 끼리 확인하기

# %%
Book_keyword1 = pd.read_csv("C:/Users/th760/OneDrive/바탕 화면/rpa 과제 자료파일/도서 키워드/도서 키워드/NL_BO_TAG_CLOUD4_202012-1.csv")
columns_to_convert = ['ISBN_NO']
Book_keyword1[columns_to_convert] = Book_keyword1[columns_to_convert].astype('string')
Book_keyword1
# Out:
# C:\Users\th760\AppData\Local\Temp\ipykernel_8664\3033470763.py:1: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   Book_keyword1 = pd.read_csv("C:/Users/th760/OneDrive/바탕 화면/rpa 과제 자료파일/도서 키워드/도서 키워드/NL_BO_TAG_CLOUD4_202012-1.csv")
#                ISBN_NO             WRD_NM  FQ_CO  ONE_WGHTVAL_VALUE  \
# 0        0051488005995  EllenPotter피터레이놀즈      2                  0
# 1        0051488005995          PenguinUS      2                  0
# 2        0051488005995       OliviaKidney      2                  0
# 3        1111111111111             자연과학수학      2                  0
# 4        1111111111111                 키움      2                  0
# ...                ...                ...    ...                ...
# 2999995  9788959750788               자본주의      1                  1
# 2999996  9788959750788                 걱정      1                  1
# 2999997  9788959750788                보유세      1                  1
# ...

# %%
Book_keyword1.dtypes
# Out:
# ISBN_NO                string[python]
# WRD_NM                         object
# FQ_CO                           int64
# ONE_WGHTVAL_VALUE               int64
# TWO_WGHTVAL_VALUE               int64
# THREE_WGHTVAL_VALUE             int64
# dtype: object

# %%
Book_keyword1['ISBN_NO'].value_counts()
# Out:
# ISBN_NO
# 9788959060726    1817
# 9788959060719    1817
# 9788959060757    1817
# 9788959060733    1817
# 9788959060740    1817
#                  ...
# 9788960975545       1
# 9788937814501       1
# 9788965421696       1
# 9788958382577       1
# 9791186536605       1
# Name: count, Length: 32288, dtype: Int64

# %%
Book_keyword2 = pd.read_csv("C:/Users/th760/OneDrive/바탕 화면/rpa 과제 자료파일/도서 키워드/도서 키워드/NL_BO_TAG_CLOUD4_202012-2.csv")
columns_to_convert = ['ISBN_NO']
Book_keyword2[columns_to_convert] = Book_keyword2[columns_to_convert].astype('string')
Book_keyword2
# Out:
#                ISBN_NO WRD_NM  FQ_CO  ONE_WGHTVAL_VALUE  TWO_WGHTVAL_VALUE  \
# 0        9788959750788     안정      1                  1                  0
# 1        9788959750788     규제      1                  1                  0
# 2        9788959750788     포털      1                  1                  0
# 3        9788959750788     관료      1                  1                  0
# 4        9788959750788     당첨      1                  1                  0
# ...                ...    ...    ...                ...                ...
# 2999995  9791187373278     위협      1                  1                  0
# 2999996  9791187373261    대학가      1                  1                  0
# 2999997  9791187373261    공업화      1                  1                  0
# 2999998  9791187373261     실체      1                  1                  0
# 2999999  9791187373278     출현      1                  1                  0
#
#          THREE_WGHTVAL_VALUE
# 0                          0
# ...

# %%
Book_keyword2['ISBN_NO'].value_counts()
# Out:
# ISBN_NO
# 9788960533943    1187
# 9791195865499    1159
# 9788960533875    1153
# 9788960531680    1149
# 9788960530423    1114
#                  ...
# 9788960610613       1
# 9788984012196       1
# 9791161715827       1
# 9791155351246       1
# 9791128840692       1
# Name: count, Length: 28405, dtype: Int64

# %%
Book_keyword1_Book_keyword2 = pd.merge(Book_keyword1, Book_keyword2, on='ISBN_NO', how='inner')
print(Book_keyword1_Book_keyword2['ISBN_NO'])
                                  # Book_keyword1, Book_keyword2 두개 데이터 테이블이 ISBN_NO 컬럼 겹치는게 3338개다.
# Out:
# 0         9788901072456
# 1         9788901072456
# 2         9788901072456
# 3         9788901072456
# 4         9788901072456
#               ...
# 428424    9788959750863
# 428425    9788959750863
# 428426    9788959750863
# 428427    9788959750863
# 428428    9788959750863
# Name: ISBN_NO, Length: 428429, dtype: string

# %%
Book_keyword3 = pd.read_csv("C:/Users/th760/OneDrive/바탕 화면/rpa 과제 자료파일/도서 키워드/도서 키워드/NL_BO_TAG_CLOUD4_202012-3.csv")
Book_keyword3.dtypes
columns_to_convert = ['ISBN_NO']
Book_keyword3[columns_to_convert] = Book_keyword3[columns_to_convert].astype('string')
Book_keyword3
# Out:
# C:\Users\th760\AppData\Local\Temp\ipykernel_8664\3573132286.py:1: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   Book_keyword3 = pd.read_csv("C:/Users/th760/OneDrive/바탕 화면/rpa 과제 자료파일/도서 키워드/도서 키워드/NL_BO_TAG_CLOUD4_202012-3.csv")
#                ISBN_NO WRD_NM  FQ_CO  ONE_WGHTVAL_VALUE  TWO_WGHTVAL_VALUE  \
# 0        9791187373261     피력      1                  1                  0
# 1        9791187373261     결과      1                  1                  0
# 2        9791187373285     싸움      1                  1                  0
# 3        9791187373285     중지      1                  1                  0
# 4        9791187373285     변란      1                  1                  0
# ...                ...    ...    ...                ...                ...
# 2999995  9788931440720    활용법      1                  1                  0
# 2999996  9788931440720     변천      1                  1                  0
# ...

# %%
Book_keyword2_Book_keyword3 = pd.merge(Book_keyword2, Book_keyword3, on = 'ISBN_NO', how = 'inner')
Book_keyword2_Book_keyword3      # Book_keyword2와 Book_keyword3 의 겹치는 ISBN_NO	가 1146476개??? 너무 많은데?
# Out:
#                ISBN_NO WRD_NM_x  FQ_CO_x  ONE_WGHTVAL_VALUE_x  \
# 0        9788970129815       기억        1                    1
# 1        9788970129815       기록        1                    1
# 2        9788970129815       유년        1                    1
# 3        9788970129815     뒷바라지        1                    1
# 4        9788970129815      막내딸        1                    1
# ...                ...      ...      ...                  ...
# 1146471  9791187373285       사망        1                    1
# 1146472  9791187373285       사망        1                    1
# 1146473  9791187373285       사망        1                    1
# 1146474  9791187373285       사망        1                    1
# 1146475  9791187373285       사망        1                    1
#
#          TWO_WGHTVAL_VALUE_x  THREE_WGHTVAL_VALUE_x WRD_NM_y  FQ_CO_y  \
# 0                          0                      0      아파트        1
# 1                          0                      0      아파트        1
# ...

# %%
Book_keyword4 = pd.read_csv("C:/Users/th760/OneDrive/바탕 화면/rpa 과제 자료파일/도서 키워드/도서 키워드/NL_BO_TAG_CLOUD4_202012-4.csv")
columns_to_convert = ['ISBN_NO']
Book_keyword4[columns_to_convert] = Book_keyword4[columns_to_convert].astype('string')
Book_keyword4
# Out:
#                ISBN_NO WRD_NM  FQ_CO  ONE_WGHTVAL_VALUE  TWO_WGHTVAL_VALUE  \
# 0        9788931440720     사례      1                  1                  0
# 1        9788931440720     다수      1                  1                  0
# 2        9788931440720    활성화      1                  1                  0
# 3        9788931440720     형성      1                  1                  0
# 4        9788931440720     가능      1                  1                  0
# ...                ...    ...    ...                ...                ...
# 2999994  9791155425107     확립      1                  1                  0
# 2999995  9791155425107     여걸      1                  1                  0
# 2999996  9791155425107     왕도      1                  1                  0
# 2999997  9791155425107     해답      1                  1                  0
# 2999998  9791155425107     지도      1                  1                  0
#
#          THREE_WGHTVAL_VALUE
# 0                          0
# ...

# %%
Book_keyword5 = pd.read_csv("C:/Users/th760/OneDrive/바탕 화면/rpa 과제 자료파일/도서 키워드/도서 키워드/NL_BO_TAG_CLOUD4_202012-5.csv")
columns_to_convert = ['ISBN_NO']
Book_keyword5[columns_to_convert] = Book_keyword5[columns_to_convert].astype('string')
Book_keyword5
# Out:
# C:\Users\th760\AppData\Local\Temp\ipykernel_8664\1804202359.py:1: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   Book_keyword5 = pd.read_csv("C:/Users/th760/OneDrive/바탕 화면/rpa 과제 자료파일/도서 키워드/도서 키워드/NL_BO_TAG_CLOUD4_202012-5.csv")
#                ISBN_NO WRD_NM  FQ_CO  ONE_WGHTVAL_VALUE  TWO_WGHTVAL_VALUE  \
# 0        9791155425107   국사학과      1                  1                  0
# 1        9791155425107   수렴청정      1                  1                  0
# 2        9791155425107     포용      1                  1                  0
# 3        9791155425107     임무      1                  1                  0
# 4        9791155425107     탁월      1                  1                  0
# ...                ...    ...    ...                ...                ...
# 2999992  9791187158134    휴대폰      2                  2                  0
# 2999993  9791187158134     지도      2                  2                  0
# ...

# %%
Book_keyword6 = pd.read_csv("C:/Users/th760/OneDrive/바탕 화면/rpa 과제 자료파일/도서 키워드/도서 키워드/NL_BO_TAG_CLOUD4_202012-6.csv")
columns_to_convert = ['ISBN_NO']
Book_keyword6[columns_to_convert] = Book_keyword5[columns_to_convert].astype('string')
Book_keyword6
# Out:
#                ISBN_NO     WRD_NM  FQ_CO  ONE_WGHTVAL_VALUE  \
# 0        9791155425107       영어일반      2                  0
# 1        9791155425107         수년      2                  2
# 2        9791155425107  MikeHwang      2                  0
# 3        9791155425107         자신      2                  2
# 4        9791155425107         기존      2                  2
# ...                ...        ...    ...                ...
# 1846336  9788901084992         선정      1                  0
# 1846337  9788901084992         바람      1                  0
# 1846338  9788901084992         국내      1                  0
# 1846339  9788901084992         호수      1                  0
# 1846340  9788901084992        작품성      1                  0
#
#          TWO_WGHTVAL_VALUE  THREE_WGHTVAL_VALUE
# 0                        1                    0
# 1                        0                    0
# 2                        1                    0
# 3                        0                    0
# ...

# %%
Book_keyword_202012_master = pd.concat([Book_keyword1, Book_keyword2, Book_keyword3, Book_keyword4, Book_keyword5, Book_keyword6], ignore_index=True)
Book_keyword_202012_master      # 전부 concat한 이유는 이 도서 키워드 들이 ISBN_NO	가 겹쳐있어도 WRD_NM(검색 단어명)은 각 Book_keyword마다 다를 수 있기에 merge를 안하고 concat를 했다.
# Out:
#                 ISBN_NO             WRD_NM  FQ_CO  ONE_WGHTVAL_VALUE  \
# 0         0051488005995  EllenPotter피터레이놀즈      2                  0
# 1         0051488005995          PenguinUS      2                  0
# 2         0051488005995       OliviaKidney      2                  0
# 3         1111111111111             자연과학수학      2                  0
# 4         1111111111111                 키움      2                  0
# ...                 ...                ...    ...                ...
# 16846332  9788901084992                 선정      1                  0
# 16846333  9788901084992                 바람      1                  0
# 16846334  9788901084992                 국내      1                  0
# 16846335  9788901084992                 호수      1                  0
# 16846336  9788901084992                작품성      1                  0
#
#           TWO_WGHTVAL_VALUE  THREE_WGHTVAL_VALUE
# 0                         1                    0
# ...

# %%
ISBN_NO_9788901084992 = Book_keyword_202012_master[Book_keyword_202012_master['ISBN_NO'] == '9788901084992']
ISBN_NO_9788901084992   # 혹시나 전부 concat한 도서키워드에서 개별적인 ISBN_NO 값마다 WRD_NM(검색단어명)이 각각 개별적인지 확인하기 위해여 이렇게 9788901084992이라는 개별값을 입력했다.
# Out:
#                 ISBN_NO WRD_NM  FQ_CO  ONE_WGHTVAL_VALUE  TWO_WGHTVAL_VALUE  \
# 234123    9788901084992    탐험대      1                  1                  0
# 234124    9788901084992     작물      1                  1                  0
# 234125    9788901084992   종교개혁      1                  1                  0
# 234126    9788901084992     불화      1                  1                  0
# 234127    9788901084992     영향      1                  1                  0
# ...                 ...    ...    ...                ...                ...
# 16846332  9788901084992     선정      1                  0                  0
# 16846333  9788901084992     바람      1                  0                  0
# 16846334  9788901084992     국내      1                  0                  0
# 16846335  9788901084992     호수      1                  0                  0
# 16846336  9788901084992    작품성      1                  0                  0
#
#           THREE_WGHTVAL_VALUE
# ...

# %%
Book_keyword_202012_master['ISBN_NO'].unique
# Out:
# <bound method Series.unique of 0           0051488005995
# 1           0051488005995
# 2           0051488005995
# 3           1111111111111
# 4           1111111111111
#                 ...
# 16846332    9788901084992
# 16846333    9788901084992
# 16846334    9788901084992
# 16846335    9788901084992
# 16846336    9788901084992
# Name: ISBN_NO, Length: 16846337, dtype: string>

# %%
Book_keyword_202012_master['ISBN_NO'].sample(50)
# Out:
# 12277877    9791186843147
# 1282322     9788952766083
# 11994683    9791155351093
# 7301232     9788990989239
# 15696295    9788949700489
# 5691420     9788982206078
# 6570802     9788988027844
# 2917360     9788959194117
# 7656933     9788991652064
# 4061234     9788965744023
# 3339020     9788960860988
# 9319116     9788934926139
# 14616272    9788932918228
# 6625353     9788988473917
# 13491151    9788901219943
# 698860      9788925505510
# 15153227    9791170261407
# 1462423     9788954413695
# 3923938     9788964808504
# 5113094     9788974747886
# 16648031    9788925562223
# 8325351     9788992975162
# 1124139     9788950906641
# 15374014    9791188230020
# 8598080     9788993854251
# 356208      9788901107066
# 12419381    9791195650446
# 1921545     9788955856002
# 7490647     9788991264496
# 14633864    9788959064465
# 8506606     9788993474084
# 10536223    9788952209825
# 5651519     9788981403683
# 3926991     9788964808832
# 3764579     9788963272047
# ...

# %%
Book_keyword_202012_master[Book_keyword_202012_master['ISBN_NO'] == '9788990062673']
# Out:
#                 ISBN_NO WRD_NM  FQ_CO  ONE_WGHTVAL_VALUE  TWO_WGHTVAL_VALUE  \
# 6957895   9788990062673     정계      1                  1                  0
# 6957896   9788990062673     전후      1                  1                  0
# 6957897   9788990062673    중산층      1                  1                  0
# 6957898   9788990062673     주변      1                  1                  0
# 6957899   9788990062673     정보      1                  1                  0
# ...                 ...    ...    ...                ...                ...
# 14426884  9788990062673     성공      2                  2                  0
# 14426885  9788990062673    프랑스      2                  2                  0
# 14426886  9788990062673  2017년      2                  0                  1
# 14426887  9788990062673    델러노      2                  2                  0
# 14426888  9788990062673    빅토르      2                  2                  0
#
#           THREE_WGHTVAL_VALUE
# ...

# %%
Book_keyword_202012_master[Book_keyword_202012_master['ISBN_NO'] == '9788990062673']['WRD_NM'].nunique()
# Out:
# 402

# %%
Book_keyword_202012_master[Book_keyword_202012_master['ISBN_NO'] == '1111111111111']
# Out:
#                 ISBN_NO              WRD_NM  FQ_CO  ONE_WGHTVAL_VALUE  \
# 3         1111111111111              자연과학수학      2                  0
# 4         1111111111111                  키움      2                  0
# 5         1111111111111  키움놀면서배우는어린이백과시리즈세트      2                  0
# 11641632  1111111111111                영어학습      2                  0
#
#           TWO_WGHTVAL_VALUE  THREE_WGHTVAL_VALUE
# 3                         1                    0
# 4                         1                    0
# 5                         1                    0
# 11641632                  1                    0

# %%
pd.set_option('display.max_rows', None)       # 이거는 데이터 프레임 중간에 ... 되는 거 해제하는 함수다. 358개라서 이정도는 확인 가능할 거 같아서 잠시 해제했다.
pd.set_option('display.max_columns', None)

# %%
ISBN_NO_9788901084992   # 해제해서 보니 2020-1~6의 WRD_NM(검색단어명)이 각 2020 쪼개진 거 마다 개별적이다.
# Out:
#                 ISBN_NO          WRD_NM  FQ_CO  ONE_WGHTVAL_VALUE  \
# 234123    9788901084992             탐험대      1                  1
# 234124    9788901084992              작물      1                  1
# 234125    9788901084992            종교개혁      1                  1
# 234126    9788901084992              불화      1                  1
# 234127    9788901084992              영향      1                  1
# 234128    9788901084992             볼거리      1                  1
# 234129    9788901084992              물리      1                  1
# 234130    9788901084992              희망      1                  1
# 234131    9788901084992            에스파냐      1                  1
# 234132    9788901084992              관심      1                  1
# 234133    9788901084992             명나라      1                  1
# 234134    9788901084992            절대왕정      1                  1
# 234135    9788901084992              약진      1                  1
# ...

# %%
ISBN_NO_9788901084992['WRD_NM'].unique()
# Out:
# array(['탐험대', '작물', '종교개혁', '불화', '영향', '볼거리', '물리', '희망', '에스파냐', '관심',
#        '명나라', '절대왕정', '약진', '볼테르', '서구', '갈릴레오', '다툼', '계급', '후유증', '소장',
#        '쇠락', '노예', '로크', '통사', '섬세', '개발', '지은', '대내', '파악', '세계무대', '루소',
#        '노력', '자신감', '내부', '베스트셀러', '부담', '연구자', '대외', '해상강국', '장면', '사회',
#        '바쿠후', '확보', '흥미', '제도', '표현', '사건', '비중', '복잡', '박윤덕', '샤자한',
#        '판화', '아기자기', '나오미양', '연구', '무력', '비주얼', '무기', '형식', '과시', '박진감',
#        '프로이센', '루이', '강희제', '대륙', '동아시아', '아메리카', '시대', '질서', '세계사', '인도',
#        '나라', '식민지', '아프리카', '경쟁', '중심', '프랑스', '청나라', '마주보는세계사교실', '발전',
#        '문화', '혁명', '아시아', '관점', '삽화', '과학', '특징', '사진', '과정', '시각',
#        '오스만튀르크', '일본', '영국', '상황', '안정', '국가', '흐름', '그림', '경제', '최신',
#        '마주보는교실', '기록화', '생생', '마주보는한국사교실', '세력', '한국사', '러시아', '균형', '재치',
#        '한눈', '현장', '누리', '진출', '통합', '중국', '번영', '독자', '이해', '경쟁력',
#        '보는역사', '약탈', '당시', '모습', '전성기', '05아시아와유럽이서로다투다', '네덜란드', '역사책',
# ...

# %%
ISBN_NO_9788901084992['WRD_NM'].nunique() # 위에 데이터 테이블에서는 358개였는데 nunique가 348개로 나오니 거의 개별적인 편이다.
# Out:
# 348

# %%
ISBN_NO_9788901084992['WRD_NM'].value_counts()
# Out:
# WRD_NM
# 표현                2
# 바다                2
# 그림                2
# 보이                2
# 일본                2
# 국제                2
# 섬세                2
# 아이                2
# 소장                2
# 영국                2
# 세밀                1
# 근거                1
# 청소년역사             1
# 자료                1
# 갈릴레이              1
# 오스트리아             1
# 좌지우지              1
# 혼란                1
# 생각                1
# 세대                1
# 부국강병              1
# 동양화               1
# 어린이               1
# 치열                1
# 술탄                1
# 무적함대              1
# 급속                1
# 확실                1
# 통치                1
# 유화                1
# 개량                1
# 공부                1
# 분량                1
# 호시탐탐              1
# 인구                1
# 조합                1
# 공간감               1
# 결국                1
# 기본                1
# 불안                1
# 후진국               1
# 계몽주의              1
# 찾아보기              1
# 편지                1
# 생활                1
# ...

# %%
Book_keyword_202012_master[Book_keyword_202012_master['ISBN_NO'] == '9788901084992']
# Out:
#                 ISBN_NO          WRD_NM  FQ_CO  ONE_WGHTVAL_VALUE  \
# 234123    9788901084992             탐험대      1                  1
# 234124    9788901084992              작물      1                  1
# 234125    9788901084992            종교개혁      1                  1
# 234126    9788901084992              불화      1                  1
# 234127    9788901084992              영향      1                  1
# 234128    9788901084992             볼거리      1                  1
# 234129    9788901084992              물리      1                  1
# 234130    9788901084992              희망      1                  1
# 234131    9788901084992            에스파냐      1                  1
# 234132    9788901084992              관심      1                  1
# 234133    9788901084992             명나라      1                  1
# 234134    9788901084992            절대왕정      1                  1
# 234135    9788901084992              약진      1                  1
# ...

# %%
# 출력 옵션 원래대로 복원 (선택사항) -> 데이터 프레임 ... 다시 제한 적용시킴.
pd.reset_option('display.max_rows')
pd.reset_option('display.max_columns')

# %%
Book_keyword_202012_master
# Out:
#                 ISBN_NO             WRD_NM  FQ_CO  ONE_WGHTVAL_VALUE  \
# 0         0051488005995  EllenPotter피터레이놀즈      2                  0
# 1         0051488005995          PenguinUS      2                  0
# 2         0051488005995       OliviaKidney      2                  0
# 3         1111111111111             자연과학수학      2                  0
# 4         1111111111111                 키움      2                  0
# ...                 ...                ...    ...                ...
# 16846332  9788901084992                 선정      1                  0
# 16846333  9788901084992                 바람      1                  0
# 16846334  9788901084992                 국내      1                  0
# 16846335  9788901084992                 호수      1                  0
# 16846336  9788901084992                작품성      1                  0
#
#           TWO_WGHTVAL_VALUE  THREE_WGHTVAL_VALUE
# 0                         1                    0
# ...

# %%
Book_keyword_202012_master.sample(50)
# Out:
#                 ISBN_NO WRD_NM  FQ_CO  ONE_WGHTVAL_VALUE  TWO_WGHTVAL_VALUE  \
# 3733519   9788962911503  제주대학교      2                  2                  0
# 6108439   9788984140585     이유      1                  1                  0
# 2055886   9788956371047     논문      2                  2                  0
# 5934080   9788983894359     독일      1                  1                  0
# 13674925  9788960177765     사망      1                  1                  0
# 4490777   9788971390818    사당동      1                  1                  0
# 16355885  9791185585413  자음과모음      2                  0                  0
# 6933279   9788990019059  소드마스터      1                  1                  0
# 16023030  9791130445090     유명      1                  0                  0
# 9583182   9788936423308    한국시      3                  1                  1
# 11554172  9788996327721     모습      1                  1                  0
# ...

# %%
condition = Book_keyword_202012_master['FQ_CO'] != (Book_keyword_202012_master['ONE_WGHTVAL_VALUE'] + Book_keyword_202012_master['TWO_WGHTVAL_VALUE'] + Book_keyword_202012_master['THREE_WGHTVAL_VALUE'])
Book_keyword_202012_master.loc[condition, 'FQ_CO'] = Book_keyword_202012_master['ONE_WGHTVAL_VALUE'] + Book_keyword_202012_master['TWO_WGHTVAL_VALUE'] + Book_keyword_202012_master['THREE_WGHTVAL_VALUE']
# 거의 ONE_WGHTVAL_VALUE,	TWO_WGHTVAL_VALUE,	THREE_WGHTVAL_VALUE 이 세 컬럼의 합은 FQ_CO이다. 근데 종종 몇개 안 맞는 경우가 있어서
# ONE_WGHTVAL_VALUE,	TWO_WGHTVAL_VALUE,	THREE_WGHTVAL_VALUE 이 세 컬럼의 합이 FQ_CO가 되게 맞춰주었다.

# %%
Book_keyword_202012_master.sample(50) # 바꾸고 맞는지 확인해봄.
# Out:
#                 ISBN_NO WRD_NM  FQ_CO  ONE_WGHTVAL_VALUE  TWO_WGHTVAL_VALUE  \
# 4638621   9788972081708     거울      1                  1                  0
# 14736979  9788955618402     초봄      1                  1                  0
# 689727    9788925502014    네티즌      1                  1                  0
# 1892828   9788955725520    토담이      1                  0                  0
# 9830714   9788937489327     생존      1                  1                  0
# 14821827  9791133471423     인공      6                  6                  0
# 13559512  9788957335741    알려진      1                  1                  0
# 6760574   9788989370352    꽃구름      1                  1                  0
# 7454379   9788991207073   일파만파      1                  1                  0
# 15460535  9791196075712     겸비      1                  1                  0
# 7137876   9788990627704     선발      1                  1                  0
# ...

# %%
Book_keyword_202012_master.groupby('ISBN_NO').FQ_CO.sum()
# Out:
# ISBN_NO
# 0051488005995      3
# 1111111111111      4
# 2013041210061      2
# 2090000056501     16
# 2909100039810      3
#                 ...
# 9791196415204    683
# 9791196420307      1
# 9791196438814      1
# 9791196460310     80
# K000462434686     31
# Name: FQ_CO, Length: 113042, dtype: int64

# %%
Book_keyword_202012_master_fix = pd.DataFrame({'FQ_CO.sum()': Book_keyword_202012_master.groupby('ISBN_NO').FQ_CO.sum()})
Book_keyword_202012_master_fix
# Out:
#                FQ_CO.sum()
# ISBN_NO
# 0051488005995            3
# 1111111111111            4
# 2013041210061            2
# 2090000056501           16
# 2909100039810            3
# ...                    ...
# 9791196415204          683
# 9791196420307            1
# 9791196438814            1
# 9791196460310           80
# K000462434686           31
#
# [113042 rows x 1 columns]

# %%
Book_keyword_202012_master_fix.reset_index(inplace=True)
Book_keyword_202012_master_fix
# Out:
#               ISBN_NO  FQ_CO.sum()
# 0       0051488005995            3
# 1       1111111111111            4
# 2       2013041210061            2
# 3       2090000056501           16
# 4       2909100039810            3
# ...               ...          ...
# 113037  9791196415204          683
# 113038  9791196420307            1
# 113039  9791196438814            1
# 113040  9791196460310           80
# 113041  K000462434686           31
#
# [113042 rows x 2 columns]

# %% [markdown]
# # 반감기 데이터와 도서 키워드를 merge

# %%
NL_LON_HALFLIFE.dtypes
# Out:
# BOOK_MASTR_SEQ_NO                int64
# ISBN_NO                 string[python]
# MUMM_LON_HALFLIFE_CO             int64
# MXMM_LON_HALFLIFE_CO             int64
# AVRG_LON_HALFLIFE_CO             int64
# BOOK_CO                          int64
# dtype: object

# %%
columns_to_convert = ['ISBN_NO']
NL_LON_HALFLIFE[columns_to_convert] = NL_LON_HALFLIFE[columns_to_convert].astype('string')

# %%
NL_LON_HALFLIFE.dtypes
# Out:
# BOOK_MASTR_SEQ_NO                int64
# ISBN_NO                 string[python]
# MUMM_LON_HALFLIFE_CO             int64
# MXMM_LON_HALFLIFE_CO             int64
# AVRG_LON_HALFLIFE_CO             int64
# BOOK_CO                          int64
# dtype: object

# %% [markdown]
# * 일단 반감기와 2020의 키워드 merge

# %%
NL_LON_HALFLIFE_Book_keyword_202012 = pd.merge(left = NL_LON_HALFLIFE, right = Book_keyword_202012_master_fix, on = 'ISBN_NO', how = 'inner') 
NL_LON_HALFLIFE_Book_keyword_202012
# Out:
#         BOOK_MASTR_SEQ_NO        ISBN_NO  MUMM_LON_HALFLIFE_CO  \
# 0                  116864  9788987999838                  1590
# 1                  117000  9788984970939                  1354
# 2                  117020  9788973374328                  1793
# 3                  117040  9788980382248                  1941
# 4                  117049  9788982814327                   508
# ...                   ...            ...                   ...
# 110571            5346795  9791163711643                   335
# 110572            5346981  9788972215783                   151
# 110573            5347418  9788960535657                   443
# 110574            5347534  9791161980485                   451
# 110575            5347968  9788932034911                   541
#
#         MXMM_LON_HALFLIFE_CO  AVRG_LON_HALFLIFE_CO  BOOK_CO  FQ_CO.sum()
# 0                       7062                  5224      156          201
# ...
