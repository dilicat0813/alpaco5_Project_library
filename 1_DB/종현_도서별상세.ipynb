# %%
import pandas as pd

# %%
df_Half = pd.read_csv("data/NL_LON_HALFLIFE_2020.csv")

# %%
df_Half.columns
# Out:
# Index(['BOOK_MASTR_SEQ_NO', 'ISBN_NO', 'MUMM_LON_HALFLIFE_CO',
#        'MXMM_LON_HALFLIFE_CO', 'AVRG_LON_HALFLIFE_CO', 'BOOK_CO'],
#       dtype='object')

# %%
df_Half.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1103283 entries, 0 to 1103282
# Data columns (total 6 columns):
#  #   Column                Non-Null Count    Dtype
# ---  ------                --------------    -----
#  0   BOOK_MASTR_SEQ_NO     1103283 non-null  int64
#  1   ISBN_NO               1103283 non-null  int64
#  2   MUMM_LON_HALFLIFE_CO  1103283 non-null  int64
#  3   MXMM_LON_HALFLIFE_CO  1103283 non-null  int64
#  4   AVRG_LON_HALFLIFE_CO  1103283 non-null  int64
#  5   BOOK_CO               1103283 non-null  int64
# dtypes: int64(6)
# memory usage: 50.5 MB

# %%
df_Detail_2019 = pd.read_csv("C:/Users/whdrk/OneDrive/바탕 화면/팀프로젝트-도서추천/도서별 상세/NL_bo_species_master_new_2019_New.csv")

# %%
df_Detail_2019.rename(columns={'isbn13':'ISBN_THIRTEEN_NO','title':'TITLE_NM','author':'AUTHR_NM','publisher':'PUBLISHER_NM'}, inplace=True)

# %%
df_Detail_2019.columns
# Out:
# Index(['?master_seq', 'ISBN_THIRTEEN_NO', 'vol', 'TITLE_NM', 'AUTHR_NM',
#        'PUBLISHER_NM', 'pub_date', 'add_code', 'price', 'img_url',
#        'description'],
#       dtype='object')

# %%
df_Detail_2019.head()
# Out:
#    ?master_seq ISBN_THIRTEEN_NO    vol
# 0    5126174.0       9.7814E+12    ebk  \
# 1    5126175.0      9.78042E+12    pbk
# 2    5126176.0       9.7802E+12    ebk
# 3    5126177.0       9.7816E+12  eisbn
# 4    5126178.0      9.78088E+12    hbk
#
#                                             TITLE_NM
# 0  (The)ecology of transportation:managing mobili...  \
# 1                                         Ecosystems
# 2                                         Ecosystems
# 3      Epidermal growth factor:methods and protocols
# 4                               Evolutionary biology
#
#                                       AUTHR_NM        PUBLISHER_NM pub_date
# 0  edited by John Davenport,Julia L. Davenport            Springer    c2006  \
# 1                Gordon Dickinson,Kevin Murphy           Routledge    c2007
# 2                Gordon Dickinson,Kevin Murphy           Routledge    c2007
# 3     edited by Tarun B. Patel,Paul J. Bertics        Humana Press    c2006
# ...

# %%
df_Detail_202012_1 = pd.read_csv("C:/Users/whdrk/OneDrive/바탕 화면/팀프로젝트-도서추천/도서별 상세/NL_BO_SPECIES_MASTER_NEW_202012-1.csv")
df_Detail_202012_2 = pd.read_csv("C:/Users/whdrk/OneDrive/바탕 화면/팀프로젝트-도서추천/도서별 상세/NL_BO_SPECIES_MASTER_NEW_202012-2.csv")
df_Detail_202012_3 = pd.read_csv("C:/Users/whdrk/OneDrive/바탕 화면/팀프로젝트-도서추천/도서별 상세/NL_BO_SPECIES_MASTER_NEW_202012-3.csv")
df_Detail_202012_4 = pd.read_csv("C:/Users/whdrk/OneDrive/바탕 화면/팀프로젝트-도서추천/도서별 상세/NL_BO_SPECIES_MASTER_NEW_202012-4.csv")
df_Detail_202012_5 = pd.read_csv("C:/Users/whdrk/OneDrive/바탕 화면/팀프로젝트-도서추천/도서별 상세/NL_BO_SPECIES_MASTER_NEW_202012-5.csv")
df_Detail_202012_1.columns
# Out:
# C:\Users\whdrk\AppData\Local\Temp\ipykernel_7560\2144206616.py:1: DtypeWarning: Columns (1,11,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_Detail_202012_1 = pd.read_csv("C:/Users/whdrk/OneDrive/바탕 화면/팀프로젝트-도서추천/도서별 상세/NL_BO_SPECIES_MASTER_NEW_202012-1.csv")
# C:\Users\whdrk\AppData\Local\Temp\ipykernel_7560\2144206616.py:2: DtypeWarning: Columns (1,7,10,11,12,13,17) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_Detail_202012_2 = pd.read_csv("C:/Users/whdrk/OneDrive/바탕 화면/팀프로젝트-도서추천/도서별 상세/NL_BO_SPECIES_MASTER_NEW_202012-2.csv")
# C:\Users\whdrk\AppData\Local\Temp\ipykernel_7560\2144206616.py:3: DtypeWarning: Columns (1,6,7,9,10,11,12,13,14,17) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_Detail_202012_3 = pd.read_csv("C:/Users/whdrk/OneDrive/바탕 화면/팀프로젝트-도서추천/도서별 상세/NL_BO_SPECIES_MASTER_NEW_202012-3.csv")
# ...

# %%
df_Detail_202101 = pd.read_csv("C:/Users/whdrk/OneDrive/바탕 화면/팀프로젝트-도서추천/도서별 상세/NL_BO_SPECIES_MASTER_NEW_202101.csv")
df_Detail_202102 = pd.read_csv("C:/Users/whdrk/OneDrive/바탕 화면/팀프로젝트-도서추천/도서별 상세/NL_BO_SPECIES_MASTER_NEW_202102.csv")
df_Detail_202103 = pd.read_csv("C:/Users/whdrk/OneDrive/바탕 화면/팀프로젝트-도서추천/도서별 상세/NL_BO_SPECIES_MASTER_NEW_202103.csv")
df_Detail_202104 = pd.read_csv("C:/Users/whdrk/OneDrive/바탕 화면/팀프로젝트-도서추천/도서별 상세/NL_BO_SPECIES_MASTER_NEW_202104.csv")
df_Detail_202105 = pd.read_csv("C:/Users/whdrk/OneDrive/바탕 화면/팀프로젝트-도서추천/도서별 상세/NL_BO_SPECIES_MASTER_NEW_202105.csv")
df_Detail_202106 = pd.read_csv("C:/Users/whdrk/OneDrive/바탕 화면/팀프로젝트-도서추천/도서별 상세/NL_BO_SPECIES_MASTER_NEW_202106.csv")
df_Detail_202107 = pd.read_csv("C:/Users/whdrk/OneDrive/바탕 화면/팀프로젝트-도서추천/도서별 상세/NL_BO_SPECIES_MASTER_NEW_202107.csv")
df_Detail_202108 = pd.read_csv("C:/Users/whdrk/OneDrive/바탕 화면/팀프로젝트-도서추천/도서별 상세/NL_BO_SPECIES_MASTER_NEW_202108.csv")
df_Detail_202109 = pd.read_csv("C:/Users/whdrk/OneDrive/바탕 화면/팀프로젝트-도서추천/도서별 상세/NL_BO_SPECIES_MASTER_NEW_202109.csv")
df_Detail_202110 = pd.read_csv("C:/Users/whdrk/OneDrive/바탕 화면/팀프로젝트-도서추천/도서별 상세/NL_BO_SPECIES_MASTER_NEW_202110.csv")
df_Detail_202111 = pd.read_csv("C:/Users/whdrk/OneDrive/바탕 화면/팀프로젝트-도서추천/도서별 상세/NL_BO_SPECIES_MASTER_NEW_202111.csv")
df_Detail_202112 = pd.read_csv("C:/Users/whdrk/OneDrive/바탕 화면/팀프로젝트-도서추천/도서별 상세/NL_BO_SPECIES_MASTER_NEW_202112.csv")
df_Detail_202112.columns
# Out:
# C:\Users\whdrk\AppData\Local\Temp\ipykernel_7560\2095601873.py:2: DtypeWarning: Columns (7,11) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_Detail_202102 = pd.read_csv("C:/Users/whdrk/OneDrive/바탕 화면/팀프로젝트-도서추천/도서별 상세/NL_BO_SPECIES_MASTER_NEW_202102.csv")
# C:\Users\whdrk\AppData\Local\Temp\ipykernel_7560\2095601873.py:4: DtypeWarning: Columns (6,17) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_Detail_202104 = pd.read_csv("C:/Users/whdrk/OneDrive/바탕 화면/팀프로젝트-도서추천/도서별 상세/NL_BO_SPECIES_MASTER_NEW_202104.csv")
# C:\Users\whdrk\AppData\Local\Temp\ipykernel_7560\2095601873.py:5: DtypeWarning: Columns (6,7,11,17) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_Detail_202105 = pd.read_csv("C:/Users/whdrk/OneDrive/바탕 화면/팀프로젝트-도서추천/도서별 상세/NL_BO_SPECIES_MASTER_NEW_202105.csv")
# ...

# %%
df_Detail_202104.isnull().sum()
# Out:
# SEQ_NO                           0
# ISBN_THIRTEEN_NO                 0
# VLM_NM                       26867
# TITLE_NM                         0
# AUTHR_NM                       139
# PUBLISHER_NM                  3452
# PBLICTE_DE                   33393
# ADTION_SMBL_NM               15117
# PRC_VALUE                    12389
# IMAGE_URL                    10310
# BOOK_INTRCN_CN               14874
# KDC_NM                       10091
# TITLE_SBST_NM                  489
# AUTHR_SBST_NM                  663
# TWO_PBLICTE_DE                9565
# INTNT_BOOKST_BOOK_EXST_AT     1235
# PORTAL_SITE_BOOK_EXST_AT      1235
# ISBN_NO                      23337
# dtype: int64

# %%
df_total = pd.concat([df_Detail_202012_1,df_Detail_202012_2,df_Detail_202012_3,df_Detail_202012_4,df_Detail_202012_5,df_Detail_202101,df_Detail_202102,
                          df_Detail_202103,df_Detail_202104,df_Detail_202105,df_Detail_202106,df_Detail_202107,df_Detail_202108,df_Detail_202109,
                          df_Detail_202110,df_Detail_202111,df_Detail_202112])
df_total.tail()
# Out:
#          SEQ_NO ISBN_THIRTEEN_NO VLM_NM
# 157113  6372497    9781191496148    NaN  \
# 157114  6372498    9781161755015    NaN
# 157115  6372499    9781197192907    NaN
# 157116  6372500    9781188005384    NaN
# 157117  6372501    9781191334426    NaN
#
#                                                  TITLE_NM
# 157113            설민석의 세계사 대모험 11 (영국 산업 혁명 편: 혁명에 맞선 자들)  \
# 157114  A Clinical Atlas: Variations of the Bones of t...
# 157115         과탑이 알려 주는 대학 생활 한 권으로 끝내기 (어서와, 대학은 처음이지?)
# 157116  중학영문법 총정리 한권으로 끝내기 (EBS강사 혼공쌤 허준석의 &quot;쉽고 재미...
# 157117                             더 빅 윈 (이룰 것인가, 남길 것인가)
#
#                    AUTHR_NM          PUBLISHER_NM PBLICTE_DE ADTION_SMBL_NM
# 157113              김정욱|설민석                  단꿈아이        NaN            NaN  \
# 157114  Thomas Dwight (지은이)  Kessinger Publishing        NaN            NaN
# 157115                  조유림                 든든한서재        NaN            NaN
# ...

# %%
#df_Detail_2019, df_total concat
df_total2 = pd.concat([df_Detail_2019,df_total])
df_total2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5789425 entries, 0 to 157117
# Data columns (total 25 columns):
#  #   Column                     Dtype
# ---  ------                     -----
#  0   ?master_seq                float64
#  1   ISBN_THIRTEEN_NO           object
#  2   vol                        object
#  3   TITLE_NM                   object
#  4   AUTHR_NM                   object
#  5   PUBLISHER_NM               object
#  6   pub_date                   object
#  7   add_code                   object
#  8   price                      object
#  9   img_url                    object
#  10  description                object
#  11  SEQ_NO                     float64
#  12  VLM_NM                     object
#  13  PBLICTE_DE                 object
#  14  ADTION_SMBL_NM             object
#  15  PRC_VALUE                  float64
#  16  IMAGE_URL                  object
#  17  BOOK_INTRCN_CN             object
#  18  KDC_NM                     object
# ...

# %%
df_total2.head()
# Out:
#    ?master_seq ISBN_THIRTEEN_NO    vol
# 0    5126174.0       9.7814E+12    ebk  \
# 1    5126175.0      9.78042E+12    pbk
# 2    5126176.0       9.7802E+12    ebk
# 3    5126177.0       9.7816E+12  eisbn
# 4    5126178.0      9.78088E+12    hbk
#
#                                             TITLE_NM
# 0  (The)ecology of transportation:managing mobili...  \
# 1                                         Ecosystems
# 2                                         Ecosystems
# 3      Epidermal growth factor:methods and protocols
# 4                               Evolutionary biology
#
#                                       AUTHR_NM        PUBLISHER_NM pub_date
# 0  edited by John Davenport,Julia L. Davenport            Springer    c2006  \
# 1                Gordon Dickinson,Kevin Murphy           Routledge    c2007
# 2                Gordon Dickinson,Kevin Murphy           Routledge    c2007
# 3     edited by Tarun B. Patel,Paul J. Bertics        Humana Press    c2006
# ...

# %%
df_total2.drop_duplicates(subset='ISBN_THIRTEEN_NO', inplace=True)

# %%
df_total2[df_total2['ISBN_THIRTEEN_NO'] == 9791156935445 ]
# Out:
#        ?master_seq ISBN_THIRTEEN_NO  vol                   TITLE_NM
# 22249          NaN    9791156935445  NaN  2020 로이어스 법전협 제2차 모의시험 해설  \
#
#                             AUTHR_NM PUBLISHER_NM pub_date add_code price
# 22249  신정훈, 김순이, 오제현, 김정철, 안준학 (지은이)         헤르메스      NaN      NaN   NaN  \
#
#       img_url  ... PRC_VALUE
# 22249     NaN  ...   43000.0  \
#
#                                                IMAGE_URL
# 22249  https://image.aladin.co.kr/product/25050/5/cov...  \
#
#                                           BOOK_INTRCN_CN KDC_NM
# 22249  로이어스 선택형, 사례형 기출 시리즈 목차를 기반으로 출제경향분석표를 정리하여 수록...    NaN  \
#
#               TITLE_SBST_NM           AUTHR_SBST_NM TWO_PBLICTE_DE
# 22249  2020로이어스법전협제2차모의시험해설  신정훈,김순이,오제현,김정철,안준학지은이     2020-09-10  \
#
#       INTNT_BOOKST_BOOK_EXST_AT PORTAL_SITE_BOOK_EXST_AT ISBN_NO
# 22249                         Y                        Y     NaN
#
# [1 rows x 25 columns]

# %%
#df_Half, df_total 머지
#merged_main = pd.merge(df_Half, df_total2,left_on='ISBN_NO', right_on='ISBN_THIRTEEN_NO', how='inner') #926648개
#merged_main = pd.merge(df_Half, df_total2,left_on='ISBN_NO', right_on='ISBN_THIRTEEN_NO', how='outer') #6151089개
merged_main = pd.merge(df_Half, df_total2,left_on='ISBN_NO', right_on='ISBN_THIRTEEN_NO', how='left') #1103283개
#merged_main = pd.merge(df_Half, df_total2,left_on='ISBN_NO', right_on='ISBN_THIRTEEN_NO', how='right') #5789425개
merged_main.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1103283 entries, 0 to 1103282
# Data columns (total 31 columns):
#  #   Column                     Non-Null Count    Dtype
# ---  ------                     --------------    -----
#  0   BOOK_MASTR_SEQ_NO          1103283 non-null  int64
#  1   ISBN_NO_x                  1103283 non-null  object
#  2   MUMM_LON_HALFLIFE_CO       1103283 non-null  int64
#  3   MXMM_LON_HALFLIFE_CO       1103283 non-null  int64
#  4   AVRG_LON_HALFLIFE_CO       1103283 non-null  int64
#  5   BOOK_CO                    1103283 non-null  int64
#  6   ?master_seq                0 non-null        float64
#  7   ISBN_THIRTEEN_NO           741619 non-null   object
#  8   vol                        0 non-null        object
#  9   TITLE_NM                   741619 non-null   object
#  10  AUTHR_NM                   736792 non-null   object
#  11  PUBLISHER_NM               691770 non-null   object
#  12  pub_date                   0 non-null        object
# ...

# %%
merged_main.rename(columns={'ISBN_NO_x':'ISBN_NO'}, inplace=True)

# %%
merged_main.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1103283 entries, 0 to 1103282
# Data columns (total 31 columns):
#  #   Column                     Non-Null Count    Dtype
# ---  ------                     --------------    -----
#  0   BOOK_MASTR_SEQ_NO          1103283 non-null  int64
#  1   ISBN_NO                    1103283 non-null  object
#  2   MUMM_LON_HALFLIFE_CO       1103283 non-null  int64
#  3   MXMM_LON_HALFLIFE_CO       1103283 non-null  int64
#  4   AVRG_LON_HALFLIFE_CO       1103283 non-null  int64
#  5   BOOK_CO                    1103283 non-null  int64
#  6   ?master_seq                0 non-null        float64
#  7   ISBN_THIRTEEN_NO           741619 non-null   object
#  8   vol                        0 non-null        object
#  9   TITLE_NM                   741619 non-null   object
#  10  AUTHR_NM                   736792 non-null   object
#  11  PUBLISHER_NM               691770 non-null   object
#  12  pub_date                   0 non-null        object
# ...

# %%
merged_main.head()
# Out:
#    BOOK_MASTR_SEQ_NO        ISBN_NO  MUMM_LON_HALFLIFE_CO
# 0             116165  9788975486456                  2765  \
# 1             116168  9788976820624                   807
# 2             116171  9788977990401                   835
# 3             116175  9788972783497                  2566
# 4             116177  9788932105635                  2806
#
#    MXMM_LON_HALFLIFE_CO  AVRG_LON_HALFLIFE_CO  BOOK_CO  ?master_seq
# 0                  5281                  4463        8          NaN  \
# 1                  6521                  4891       43          NaN
# 2                  6759                  4555       60          NaN
# 3                  4133                  3334        7          NaN
# 4                  2806                  2806        1          NaN
#
#   ISBN_THIRTEEN_NO  vol                    TITLE_NM  ... PRC_VALUE
# 0    9788975486456  NaN            (L=MS²학문의 기원)學習學  ...   16000.0  \
# 1    9788976820624  NaN                         골콘다  ...   12000.0
# ...

# %%
merged_main.to_csv('Details2.csv', index = False)

# %%
merged_main[merged_main["AUTHR_NM"].isnull()].sample(10)
# Out:
#          BOOK_MASTR_SEQ_NO        ISBN_NO  MUMM_LON_HALFLIFE_CO
# 1034238            3880998  9788953908291                  3713  \
# 1033706            3879314  9791156300281                   585
# 848440             3159642  9789810983529                    91
# 186900             1198282  9788996687511                  1354
# 263365             1817773  9788978810715                  4151
# 172755             1149123  9788972839323                  2869
# 826000             3089823  9780545256384                   506
# 726307             2838333  9788993546842                  2224
# 546804             2551796  9781444918168                  1050
# 730672             2844371  9788996442712                  1851
#
#          MXMM_LON_HALFLIFE_CO  AVRG_LON_HALFLIFE_CO  BOOK_CO  ?master_seq
# 1034238                  3713                  3713        2          NaN  \
# 1033706                  1772                   893        4          NaN
# ...

# %%
merged_main[merged_main["KDC_NM"].isnull()]
# Out:
#          BOOK_MASTR_SEQ_NO        ISBN_NO  MUMM_LON_HALFLIFE_CO
# 291                 117710  9780071357692                  5018  \
# 292                 117790  9780446677455                  1226
# 293                 118030  9781563976148                  2132
# 294                 118089  9781578511440                  4239
# 295                 118188  9780471353997                  4072
# ...                    ...            ...                   ...
# 1103195            5939660  9781590695521                  1809
# 1103196            5939668  9788925922959                  4289
# 1103197            5939669  9788910579175                  3897
# 1103198            5939681  9788930238292                   171
# 1103271            5952747  9785717700771                    10
#
#          MXMM_LON_HALFLIFE_CO  AVRG_LON_HALFLIFE_CO  BOOK_CO ISBN_THIRTEEN_NO
# 291                      5018                  5018        1    9780071357692  \
# ...

# %%
#merged_main.drop(['vol','VLM_NM','TITLE_SBST_NM','AUTHR_SBST_NM','TWO_PBLICTE_DE','INTNT_BOOKST_BOOK_EXST_AT','PORTAL_SITE_BOOK_EXST_AT','ISBN_NO_y'],axis=1, inplace=True)

# %%
#merged_main.drop('PRC_VALUE', axis=1, inplace=True)

# %%
merged_main.isnull().sum()
# Out:
# BOOK_MASTR_SEQ_NO            0
# ISBN_NO                      0
# MUMM_LON_HALFLIFE_CO         0
# MXMM_LON_HALFLIFE_CO         0
# AVRG_LON_HALFLIFE_CO         0
# BOOK_CO                      0
# ISBN_THIRTEEN_NO        361664
# TITLE_NM                361664
# AUTHR_NM                366491
# PUBLISHER_NM            411513
# SEQ_NO                  361664
# ADTION_SMBL_NM          537603
# IMAGE_URL               507449
# BOOK_INTRCN_CN          557006
# KDC_NM                  511080
# dtype: int64
