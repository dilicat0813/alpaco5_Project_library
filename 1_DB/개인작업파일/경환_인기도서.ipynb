# %%
import pandas as pd

# %%
df1 = pd.read_csv("data/인기도서/NL_BO_BEST_LOAN_BOOK_HISTORY_202101.csv")
df2 = pd.read_csv("data/인기도서/NL_BO_BEST_LOAN_BOOK_HISTORY_202102.csv")
df3 = pd.read_csv("data/인기도서/NL_BO_BEST_LOAN_BOOK_HISTORY_202103.csv")
df4 = pd.read_csv("data/인기도서/NL_BO_BEST_LOAN_BOOK_HISTORY_202104.csv")
df5 = pd.read_csv("data/인기도서/NL_BO_BEST_LOAN_BOOK_HISTORY_202105.csv")
df6 = pd.read_csv("data/인기도서/NL_BO_BEST_LOAN_BOOK_HISTORY_202106.csv")
df7 = pd.read_csv("data/인기도서/NL_BO_BEST_LOAN_BOOK_HISTORY_202107.csv")
df8 = pd.read_csv("data/인기도서/NL_BO_BEST_LOAN_BOOK_HISTORY_202108.csv")
df9 = pd.read_csv("data/인기도서/NL_BO_BEST_LOAN_BOOK_HISTORY_202109.csv")
df10 = pd.read_csv("data/인기도서/NL_BO_BEST_LOAN_BOOK_HISTORY_202110.csv")
df11 = pd.read_csv("data/인기도서/NL_BO_BEST_LOAN_BOOK_HISTORY_202111.csv")
df12 = pd.read_csv("data/인기도서/NL_BO_BEST_LOAN_BOOK_HISTORY_202112.csv")
# Out:
# C:\Users\mkh08\AppData\Local\Temp\ipykernel_30560\4129151692.py:1: DtypeWarning: Columns (20) have mixed types. Specify dtype option on import or set low_memory=False.
#   df1 = pd.read_csv("data/인기도서/NL_BO_BEST_LOAN_BOOK_HISTORY_202101.csv")
# C:\Users\mkh08\AppData\Local\Temp\ipykernel_30560\4129151692.py:3: DtypeWarning: Columns (20) have mixed types. Specify dtype option on import or set low_memory=False.
#   df3 = pd.read_csv("data/인기도서/NL_BO_BEST_LOAN_BOOK_HISTORY_202103.csv")
# C:\Users\mkh08\AppData\Local\Temp\ipykernel_30560\4129151692.py:5: DtypeWarning: Columns (3,20) have mixed types. Specify dtype option on import or set low_memory=False.
#   df5 = pd.read_csv("data/인기도서/NL_BO_BEST_LOAN_BOOK_HISTORY_202105.csv")
# C:\Users\mkh08\AppData\Local\Temp\ipykernel_30560\4129151692.py:6: DtypeWarning: Columns (18,20) have mixed types. Specify dtype option on import or set low_memory=False.
#   df6 = pd.read_csv("data/인기도서/NL_BO_BEST_LOAN_BOOK_HISTORY_202106.csv")
# ...

# %%
df = pd.concat([df1,df2,df3,df4,df5,df6, df7, df8, df9, df10, df11, df12])

# %%
df = df[df['ANALS_TY_CD_NM']=="연령 및 성별"]

# %%
df = df[df['RANK_CO'] <= 10]

# %%
df_p1 = df[df['ANALS_PD_CD']=="p1"]

# %%
df_p1
# Out:
#            SEQ_NO  RANK_CO     INPT_DE ISBN_THIRTEEN_NO  \
# 17250   253578951        2  2021-01-15    9791191119305
# 17251   253578952        5  2021-01-15    9788934992301
# 17252   253578953        5  2021-01-15    9788936434441
# 17253   253578954        5  2021-01-15    9788973378166
# 17254   253578955        5  2021-01-15    9791186900789
# ...           ...      ...         ...              ...
# 188892  309272497        1  2021-12-15    9791164063734
# 188894  309272499        3  2021-12-15    9791164060931
# 188895  309272498        1  2021-12-15    9791164135592
# 188896  309290501        5  2021-12-15    9791164062287
# 188897  309282498        2  2021-12-15    9791188874293
#
#                  BOOK_TITLE_NM                            AUTHR_NM  \
# 17250   그럼에도 불구하고 :공지영의 섬진 산책                             지은이: 공지영
# 17251         목마름 :요 네스뵈 장편소설                 지은이: 요 네스뵈 ;옮긴이: 문희경
# 17252          연년세세 :황정은 연작소설                             지은이: 황정은
# ...

# %%
df.describe()
# Out:
#              SEQ_NO       RANK_CO  BOOK_MASTR_SEQ_NO        LON_CO  \
# count  1.460600e+04  14606.000000       1.460600e+04  14606.000000
# mean   2.800484e+08      5.458305       4.522325e+06    188.210804
# std    1.724164e+07      2.847416       1.405941e+06    284.780669
# min    2.535619e+08      1.000000       1.264790e+05      2.000000
# 25%    2.677170e+08      3.000000       3.416063e+06     22.000000
# 50%    2.780427e+08      5.000000       5.424120e+06     78.000000
# 75%    2.936074e+08      8.000000       5.678862e+06    226.000000
# max    3.094215e+08     10.000000       6.293680e+06   2541.000000
#
#         ANALS_TY_CD  ANALS_LON_TOT_CO
# count  14606.000000      1.460600e+04
# mean       4.499384      4.888851e+05
# std        0.500017      8.111483e+05
# min        4.000000      1.908000e+03
# 25%        4.000000      4.819100e+04
# 50%        4.000000      1.949620e+05
# 75%        5.000000      5.777200e+05
# max        5.000000      5.257419e+06

# %%
df_rank1 = df[df['RANK_CO'] == 1]

# %%
df_rank1_20 = df_rank1[df_rank1['AGE_FLAG_NM']=="20대"]

# %%
df_rank1_20
# Out:
#            SEQ_NO  RANK_CO     INPT_DE ISBN_THIRTEEN_NO  \
# 28539   253587948        1  2021-01-15    9788994702346
# 116472  253588948        1  2021-01-15    9791190090018
# 161340  253712948        1  2021-01-15    9788972756194
# 180322  253569948        1  2021-01-15    9788994702346
# 180332  253570948        1  2021-01-15    9791190090018
# ...           ...      ...         ...              ...
# 188557  309349497        1  2021-12-15    9788934972464
# 188570  309350497        1  2021-12-15    9791165341909
# 188754  309413497        1  2021-12-15    9791190090018
# 188780  309412497        1  2021-12-15    9788934972464
# 188932  309394497        1  2021-12-15    9788934972464
#
#                                   BOOK_TITLE_NM                 AUTHR_NM  \
# 28539      부의 추월차선 :부자들이 말해 주지 않는 진정한 부를 얻는 방법        엠제이 드마코 지음 ;신소영 옮김
# 116472              우리가 빛의 속도로 갈 수 없다면 :김초엽 소설                  지은이: 김초엽
# ...

# %%
df[df['ISBN_THIRTEEN_NO']==9788934972464	]
# Out:
#            SEQ_NO  RANK_CO     INPT_DE ISBN_THIRTEEN_NO  \
# 185965  253575948        1  2021-01-15    9788934972464
# 186076  253593948        1  2021-01-15    9788934972464
# 178304  258798132        1  2021-02-15    9788934972464
# 179143  258816132        1  2021-02-15    9788934972464
# 184408  258860132        1  2021-02-15    9788934972464
# 184558  258878132        1  2021-02-15    9788934972464
# 162481  263403440        1  2021-03-16    9788934972464
# 188401  263322440        1  2021-03-16    9788934972464
# 188552  263340440        1  2021-03-16    9788934972464
# 188928  263385440        1  2021-03-16    9788934972464
# 181839  267867912        1  2021-04-15    9788934972464
# 181940  267849912        1  2021-04-15    9788934972464
# 107862  278025694        1  2021-06-15    9788934972464
# 125871  278043694        1  2021-06-15    9788934972464
# 188395  298745497        1  2021-10-15    9788934972464
# 188546  298763497        1  2021-10-15    9788934972464
# ...
