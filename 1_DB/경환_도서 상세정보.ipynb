# %%
import pandas as pd

# %%
# df = pd.read_csv("data/도서별 상세/NL_bo_species_master_new_2019_new.csv")

# %%
# df = df.dropna(subset=['?master_seq'])

# %%
df = pd.read_csv("data/도서 키워드/NL_BO_TAG_CLOUD4_202012-1.csv")

# %%
df['ONE_WGHTVAL_VALUE'].unique()
# Out:
# array([  0,   1,  53,  33,  20,  19,  16,  15,  14,  13,   9,  12,  11,
#         10,   6,   8,   5,   7,   4,   3,   2,  49,  37,  32,  23,  22,
#         35,  25,  24,  21,  77,  38,  17,  18,  81,  29,  26, 210,  46,
#         30, 162,  31,  42,  62,  45,  34,  36,  52,  65,  27,  44,  28,
#         39,  43,  50,  73,  86,  78,  63, 139, 217,  68, 164,  60,  41,
#         90,  80,  51,  91, 130, 133, 264,  64,  47,  48,  87,  72,  57,
#         40,  59,  95,  99, 126,  66,  94,  61,  55,  58,  74,  82,  97,
#        112,  56,  76,  88,  54,  71, 116,  67,  83,  79,  69, 100, 119,
#        142, 147, 121, 102,  75, 101,  70, 110, 122, 124, 125,  89,  85,
#        148, 107, 128, 117,  98, 109, 158, 103,  92, 114,  84, 108, 113,
#        111, 186, 150, 261, 170, 138, 104, 105, 141, 153, 120, 106, 115,
#        152,  93, 173], dtype=int64)

# %%
df[df['ONE_WGHTVAL_VALUE'] == 53]
# Out:
#                ISBN_NO WRD_NM  FQ_CO  ONE_WGHTVAL_VALUE  TWO_WGHTVAL_VALUE  \
# 79       8809270742090     영화     53                 53                  0
# 20348    9788901059846     동영     53                 53                  0
# 45198    9791160560503     여행     53                 53                  0
# 56005    9791186712788     수학     53                 53                  0
# 60898    9788901042367     윌리     56                 53                  0
# 326805   9788901101156     환관     53                 53                  0
# 480663   9788901158693     바다     53                 53                  0
# 640788   9788915086791     제주     53                 53                  0
# 657391   9788919204030     피부     53                 53                  0
# 687221   9788925501147     만약     53                 53                  0
# 687458   9788925501154     만약     53                 53                  0
# ...

# %%
df[df['THREE_WGHTVAL_VALUE'] == 1].sample(5)
# Out:
#                ISBN_NO   WRD_NM  FQ_CO  ONE_WGHTVAL_VALUE  TWO_WGHTVAL_VALUE  \
# 1461645  9788954408042    지성개선론      3                  0                  0
# 579144   9788915016521  끊어진지푸라기      3                  0                  0
# 1756151  9788954625241      말과활      3                  0                  0
# 104509   9781844285457   내토끼어딨어      3                  0                  0
# 1874494  9788971998441     양심경제      3                  0                  0
#
#          THREE_WGHTVAL_VALUE
# 1461645                    1
# 579144                     1
# 1756151                    1
# 104509                     1
# 1874494                    1

# %%
df[df['TWO_WGHTVAL_VALUE'] == 1].sample(5)
# Out:
#                ISBN_NO   WRD_NM  FQ_CO  ONE_WGHTVAL_VALUE  TWO_WGHTVAL_VALUE  \
# 733738   9788925514246      신서희      2                  0                  1
# 1503039  9788954419581    자음과모음      2                  0                  1
# 2003359  9788956054490      그림책      4                  2                  1
# 2797612  9788958913184      오정수      2                  0                  1
# 1779272  9788955171570  마에다타츠히코      2                  0                  1
#
#          THREE_WGHTVAL_VALUE
# 733738                     0
# 1503039                    0
# 2003359                    0
# 2797612                    0
# 1779272                    0
