# %%
import pandas as pd

# %%
df1 = pd.read_csv('data/NL_LON_HALFLIFE_202008.csv')
df2 = pd.read_csv('data/NL_ON_SPECIES_ANALYSIS_MASTER_202112.csv')
# Out:
# c:\Users\mkh08\miniconda3\envs\py3.10\lib\site-packages\IPython\core\interactiveshell.py:3505: DtypeWarning: Columns (1) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# c:\Users\mkh08\miniconda3\envs\py3.10\lib\site-packages\IPython\core\interactiveshell.py:3505: DtypeWarning: Columns (2) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
df1.tail()
# Out:
#          SPECIES_MASTER_SEQ_NO        ISBN_NO  MUMM_LON_HALFLIFE_NO  \
# 1050105                5687529  9788983673107                    34
# 1050106                5688417  9788954672771                    12
# 1050107                5690737  9788969150783                    12
# 1050108                5691402  9788974461358                  4183
# 1050109                5691407  9788970902244                  4565
#
#          MXM_LON_HALFLIFE_NO  AVRG_LON_HALFLIFE_NO  BOOK_CO
# 1050105                   34                    34        1
# 1050106                   12                    12        2
# 1050107                   12                    12        1
# 1050108                 4183                  4183        1
# 1050109                 4565                  4565        1

# %%
df2.tail()
# Out:
#          BOOK_MASTR_SEQ_NO       CTRL_NO ISBN_THIRTEEN_NO       TITLE_NM  \
# 1090750            2478920  KJU201012858    9788958124917      이상한 사과나무
# 1090751            2478721  KJU201012808    9788958125181    혼자는 너무 심심해
# 1090752            2478736  KJU201012828    9788958125310  장난감 나라 대포 전쟁
# 1090753            2446221  KJU200702045    9788971962305     산수보다 쉬운 수학
# 1090754            2556992  KJU200702045    9788971962312     산수보다 쉬운 수학
#
#                   AUTHR_NM PUBLISHER_NM VLM_NM PBLCATE_DE  \
# 1090750    글: 홍건국 ;그림: 손혜란       한국헤밍웨이     17       2005
# 1090751    글: 홍건국 ;그림: 김세온       한국헤밍웨이     44       2005
# 1090752    글: 홍건국 ;그림: 김선민       한국헤밍웨이     57       2005
# 1090753  지은이: 강성오,그린이: 박향미       사계절출판사      1       1994
# 1090754  지은이: 강성오,그린이: 박향미       사계절출판사      2       1994
#
#                                                  IMAGE_URL  LON_CO  \
# 1090750                                                NaN    1450
# ...

# %%
# 두 데이터프레임을 머지
merged_df = pd.merge(df1, df2, left_on='SPECIES_MASTER_SEQ_NO', right_on='BOOK_MASTR_SEQ_NO', how='inner')
# merged_df = pd.merge(df1, df2, left_on='ISBN_NO', right_on='ISBN_THIRTEEN_NO', how='inner')

# %%
merged_df # 709475 row 살아남음  (df1 1050109, df2 1090754)
# Out:
#         SPECIES_MASTER_SEQ_NO        ISBN_NO  MUMM_LON_HALFLIFE_NO  \
# 0                      116165  9788975486456                  2492
# 1                      136707  9788952720016                  3840
# 2                      116168  9788976820624                   534
# 3                      116171  9788977990401                   562
# 4                      116175  9788972783497                  2293
# ...                       ...            ...                   ...
# 709471                5683211  9791196861162                    12
# 709472                5683275  9791158681753                    32
# 709473                5686627  9791164135592                    30
# 709474                5688417  9788954672771                    12
# 709475                5690737  9788969150783                    12
#
#         MXM_LON_HALFLIFE_NO  AVRG_LON_HALFLIFE_NO  BOOK_CO  BOOK_MASTR_SEQ_NO  \
# 0                      5008                  4183        9             116165
# ...
