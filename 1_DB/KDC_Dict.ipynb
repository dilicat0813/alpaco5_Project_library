# %%
kdc_dict_total = {
    '000': '총류',
    '100': '철학',
    '200': '종교',
    '300': '사회과학',
    '400': '자연과학',
    '500': '기술과학',
    '600': '예술',
    '700': '언어',
    '800': '문학',
    '900': '역사',
}

# %%
kdc_dict_000 = {    
    '00': '총류',
    '10': '도서학, 서지학',
    '20': '문헌정보학',
    '30': '백과사전',
    '40': '강연집, 수필집, 연설문집',
    '50': '일반연속간행물',
    '60': '일반 학회, 단체, 협회, 기관',
    '70': '신문, 저널리즘',
    '80': '일반 전집, 총서',
    '90': '향토자료',
}

# %%
kdc_dict_100 = {    
    '00': '철학',
    '10': '형이상학',
    '20': '인식론, 인과론, 인간학',
    '30': '철학의 체계',
    '40': '경학',
    '50': '동양철학, 사상',
    '60': '서양철학',
    '70': '논리학',
    '80': '심리학',
    '90': '윤리학, 도덕철학',
}

kdc_dict_200 = {    
    '00': '종교',
    '10': '비교종교학',
    '20': '불교',
    '30': '기독교',
    '40': '도교',
    '50': '천도교',
    '70': '힌두교, 브라만교',
    '80': '이슬람교(회교)',
    '90': '기타 제종교',
}

kdc_dict_300 = {    
    '00': '사회과학',
    '10': '통계학',
    '20': '경제학',
    '30': '사회학, 사회문제',
    '40': '정치학',
    '50': '행정학',
    '60': '법학',
    '70': '교육학',
    '80': '풍속, 예절, 민속학',
    '90': '국방, 군사학',
}

kdc_dict_400 = {    
    '00': '자연과학',
    '10': '수학',
    '20': '물리학',
    '30': '화학',
    '40': '천문학',
    '50': '지학',
    '60': '광물학',
    '70': '생명과학',
    '80': '식물학',
    '90': '동물학',
}

kdc_dict_500 = {    
    '00': '기술과학',
    '10': '의학',
    '20': '농업, 농학',
    '30': '공학, 공업일반',
    '40': '건축공학',
    '50': '기계공학',
    '60': '전기공학, 전자공학',
    '70': '화학공학',
    '80': '제조업',
    '90': '생활과학',
}

kdc_dict_600 = {    
    '00': '예술',
    '10': '건축술',
    '20': '조각 및 조형미술',
    '30': '공예, 장식미술',
    '40': '서예',
    '50': '회화, 도화',
    '60': '사진예술',
    '70': '음악',
    '80': '공연예술 및 매체예술',
    '90': '오락, 스포츠',
}

kdc_dict_700 = {    
    '00': '언어',
    '10': '한국어',
    '20': '중국어',
    '30': '일본어 및 기타 아시아제어',
    '40': '영어',
    '50': '독일어',
    '60': '프랑스어',
    '70': '스페인어 및 포르투갈어',
    '80': '이탈리아어',
    '90': '기타 제어',
}

kdc_dict_800 = {    
    '00': '문학',
    '10': '한국문학',
    '20': '중국문학',
    '30': '일본문학 및 기타 아시아문학',
    '40': '영미문학',
    '50': '독일문학',
    '60': '프랑스문학',
    '70': '스페인 및 포르투갈문학',
    '80': '이탈리아문학',
    '90': '기타 제문학',
}

kdc_dict_900 = {    
    '00': '역사',
    '10': '아시아',
    '20': '유럽',
    '30': '아프리카',
    '40': '북아메리카',
    '50': '남아메리카',
    '60': '오세아니아',
    '70': '양극지방',
    '80': '지리',
    '90': '전기',
}
