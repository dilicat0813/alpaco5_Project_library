# %%
kdc_dict_total = {
    '000': '총류',
    '100': '철학',
    '200': '종교',
    '300': '사회과학',
    '400': '자연과학',
    '500': '기술과학',
    '600': '예술',
    '700': '언어',
    '800': '문학',
    '900': '역사',
}

# %%
kdc_dict_000 = {    
    '00': '총류',
    '10': '도서학, 서지학',
    '20': '문헌정보학',
    '30': '백과사전',
    '40': '강연집, 수필집, 연설문집',
    '50': '일반연속간행물',
    '60': '일반 학회, 단체, 협회, 기관',
    '70': '신문, 저널리즘',
    '80': '일반 전집, 총서',
    '90': '향토자료',
}

# %%
kdc_dict_100 = {    
    '00': '철학',
    '10': '형이상학',
    '20': '인식론, 인과론, 인간학',
    '30': '철학의 체계',
    '40': '경학',
    '50': '동양철학, 사상',
    '60': '서양철학',
    '70': '논리학',
    '80': '심리학',
    '90': '윤리학, 도덕철학',
}

kdc_dict_200 = {    
    '00': '종교',
    '10': '비교종교학',
    '20': '불교',
    '30': '기독교',
    '40': '도교',
    '50': '천도교',
    '70': '힌두교, 브라만교',
    '80': '이슬람교(회교)',
    '90': '기타 제종교',
}

kdc_dict_300 = {    
    '00': '사회과학',
    '10': '통계학',
    '20': '경제학',
    '30': '사회학, 사회문제',
    '40': '정치학',
    '50': '행정학',
    '60': '법학',
    '70': '교육학',
    '80': '풍속, 예절, 민속학',
    '90': '국방, 군사학',
}

kdc_dict_00 = {    
    '00': '',
    '10': '',
    '20': '',
    '30': '',
    '40': '',
    '50': '',
    '60': '',
    '70': '',
    '80': '',
    '90': '',
}

kdc_dict_00 = {    
    '00': '',
    '10': '',
    '20': '',
    '30': '',
    '40': '',
    '50': '',
    '60': '',
    '70': '',
    '80': '',
    '90': '',
}

kdc_dict_00 = {    
    '00': '',
    '10': '',
    '20': '',
    '30': '',
    '40': '',
    '50': '',
    '60': '',
    '70': '',
    '80': '',
    '90': '',
}

kdc_dict_00 = {    
    '00': '',
    '10': '',
    '20': '',
    '30': '',
    '40': '',
    '50': '',
    '60': '',
    '70': '',
    '80': '',
    '90': '',
}

kdc_dict_00 = {    
    '00': '',
    '10': '',
    '20': '',
    '30': '',
    '40': '',
    '50': '',
    '60': '',
    '70': '',
    '80': '',
    '90': '',
}

kdc_dict_00 = {    
    '00': '',
    '10': '',
    '20': '',
    '30': '',
    '40': '',
    '50': '',
    '60': '',
    '70': '',
    '80': '',
    '90': '',
}

kdc_dict_00 = {    
    '00': '',
    '10': '',
    '20': '',
    '30': '',
    '40': '',
    '50': '',
    '60': '',
    '70': '',
    '80': '',
    '90': '',
}
