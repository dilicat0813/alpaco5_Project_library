# %%
import pandas as pd
import numpy as np

# %%
df1 = pd.read_csv('data/NL_LON_HALFLIFE_2020.csv')
df2 = pd.read_csv('data/NL_ON_SPECIES_ANALYSIS_MASTER_202112.csv')
# Out:
# c:\Users\mkh08\miniconda3\envs\py3.10\lib\site-packages\IPython\core\interactiveshell.py:3505: DtypeWarning: Columns (2) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
df1['BOOK_MASTR_SEQ_NO'] =df1['BOOK_MASTR_SEQ_NO'].astype(float)
# df1['ISBN_NO'] = df1['ISBN_NO'].astype(str)
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1103283 entries, 0 to 1103282
# Data columns (total 6 columns):
#  #   Column                Non-Null Count    Dtype
# ---  ------                --------------    -----
#  0   BOOK_MASTR_SEQ_NO     1103283 non-null  float64
#  1   ISBN_NO               1103283 non-null  int64
#  2   MUMM_LON_HALFLIFE_CO  1103283 non-null  int64
#  3   MXMM_LON_HALFLIFE_CO  1103283 non-null  int64
#  4   AVRG_LON_HALFLIFE_CO  1103283 non-null  int64
#  5   BOOK_CO               1103283 non-null  int64
# dtypes: float64(1), int64(5)
# memory usage: 50.5 MB

# %%
df2['BOOK_MASTR_SEQ_NO'] = df2['BOOK_MASTR_SEQ_NO'].astype(float)
# df2['ISBN_THIRTEEN_NO'] = df2['ISBN_THIRTEEN_NO'].astype(str)
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1090755 entries, 0 to 1090754
# Data columns (total 11 columns):
#  #   Column             Non-Null Count    Dtype
# ---  ------             --------------    -----
#  0   BOOK_MASTR_SEQ_NO  1090755 non-null  float64
#  1   CTRL_NO            1090754 non-null  object
#  2   ISBN_THIRTEEN_NO   1090755 non-null  object
#  3   TITLE_NM           1090755 non-null  object
#  4   AUTHR_NM           1090755 non-null  object
#  5   PUBLISHER_NM       1090755 non-null  object
#  6   VLM_NM             278284 non-null   object
#  7   PBLCATE_DE         1090722 non-null  object
#  8   IMAGE_URL          924837 non-null   object
#  9   LON_CO             1090755 non-null  int64
#  10  ISBN_ORGT_NO       939378 non-null   object
# dtypes: float64(1), int64(1), object(9)
# memory usage: 91.5+ MB

# %%
# 두 데이터프레임을 머지
merged_df = pd.merge(df1, df2, left_on='BOOK_MASTR_SEQ_NO', right_on='BOOK_MASTR_SEQ_NO', how='inner')
# merged_df = pd.merge(df1, df2, left_on='ISBN_NO', right_on='ISBN_THIRTEEN_NO', how='inner')
# merged_df['BOOK_CO'].unique()
merged_df
# Out:
#         BOOK_MASTR_SEQ_NO        ISBN_NO  MUMM_LON_HALFLIFE_CO  \
# 0                116165.0  9788975486456                  2765
# 1                116168.0  9788976820624                   807
# 2                116171.0  9788977990401                   835
# 3                116175.0  9788972783497                  2566
# 4                116177.0  9788932105635                  2806
# ...                   ...            ...                   ...
# 735957          5929100.0  9791164137527                    20
# 735958          5929445.0  9791164137510                    23
# 735959          5929593.0  9791190234139                     6
# 735960          5930481.0  9788954677837                     6
# 735961          5955207.0  9791197226113                    84
#
#         MXMM_LON_HALFLIFE_CO  AVRG_LON_HALFLIFE_CO  BOOK_CO       CTRL_NO  \
# 0                       5281                  4463        8  KMO200135104
# ...

# %%
# merged_df # 709476 row 살아남음  (df1 1050109, df2 1090754)
merged_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 735962 entries, 0 to 735961
# Data columns (total 16 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   BOOK_MASTR_SEQ_NO     735962 non-null  float64
#  1   ISBN_NO               735962 non-null  int64
#  2   MUMM_LON_HALFLIFE_CO  735962 non-null  int64
#  3   MXMM_LON_HALFLIFE_CO  735962 non-null  int64
#  4   AVRG_LON_HALFLIFE_CO  735962 non-null  int64
#  5   BOOK_CO               735962 non-null  int64
#  6   CTRL_NO               735962 non-null  object
#  7   ISBN_THIRTEEN_NO      735962 non-null  object
#  8   TITLE_NM              735962 non-null  object
#  9   AUTHR_NM              735962 non-null  object
#  10  PUBLISHER_NM          735962 non-null  object
#  11  VLM_NM                213406 non-null  object
#  12  PBLCATE_DE            735960 non-null  object
#  13  IMAGE_URL             630919 non-null  object
# ...

# %%
merged_df
# Out:
#         BOOK_MASTR_SEQ_NO        ISBN_NO  MUMM_LON_HALFLIFE_CO  \
# 0                116165.0  9788975486456                  2765
# 1                116168.0  9788976820624                   807
# 2                116171.0  9788977990401                   835
# 3                116175.0  9788972783497                  2566
# 4                116177.0  9788932105635                  2806
# ...                   ...            ...                   ...
# 735957          5929100.0  9791164137527                    20
# 735958          5929445.0  9791164137510                    23
# 735959          5929593.0  9791190234139                     6
# 735960          5930481.0  9788954677837                     6
# 735961          5955207.0  9791197226113                    84
#
#         MXMM_LON_HALFLIFE_CO  AVRG_LON_HALFLIFE_CO  BOOK_CO       CTRL_NO  \
# 0                       5281                  4463        8  KMO200135104
# ...

# %%
merged_df.drop(['VLM_NM','ISBN_ORGT_NO' ], axis=1, inplace=True)

# %%
merged_df.to_csv('usedata.csv')
